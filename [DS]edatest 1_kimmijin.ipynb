# %% [markdown]
# <div align="center">
#     <img src="images/zb-logo.png" alt="제로베이스" width="100%">
#     <br>
#     <a href="https://zerobaseschool.notion.site/DS-EDA-Lv-Test-b7d5e895c7cd4dda813c8fe2f2c23f79"><img src="images/openinnotion_logo.png" alt="EDA Lv Test Doc" width="12%"></a>
#
# 이 Jupyter Notebook 파일은 <a href="https://zero-base.co.kr/category_data_camp/school_DS">제로베이스</a>에서 제공하는 **EDA Level Test** 문제입니다.<br>
# 지금까지 공부하신 내용으로 데이터 분석에 대해 좀 더 연습할 수 있는 시간이 되셨으면 좋겠습니다.🙂<br>
# **EDA Level Test**에 대한 안내 사항은 상단 **Open in ZeroBase Notion** 로고를 클릭하여 확인해주세요!<br>
# 반드시 시작 전에 내용을 숙지해주시기를 바랍니다!<br>
# </div>
#
# ***

# %% [markdown]
# <h1 style="background-color:#9F81F7;color:#D8D8D8;font-weight:bold;display:inline-block;padding: 5px">EDA Level Test 01 ⭐️</h1>
#
# | Week | Data Analysis | Difficulty | This Notebook |
# |------|---------------|------------|-------|
# | 1    | 서울시 인구 데이터 | ⭐️ |👈|
# | 2    | 화장품 성분 데이터 | ⭐️⭐️⭐️ ||
# | 3    | 올림픽 데이터 | ⭐️⭐️ ||
# | 4    | 국가별 인터넷 사용률 데이터 |⭐️⭐️ ||
# | 5    | 전국 박물관/미술관 정보 표준 데이터 | ⭐️⭐️⭐️ ||
# | 6    | 서울시 흡연율 통계 데이터 | ⭐️⭐️ ||
# | 7    | 웹크롤링 | ⭐️ ||
# | 8    | 서울시 지하철 호선별 역별 유/무임 승하차 인원 정보 데이터 | ⭐️⭐️ ||
# | 9    | 서울시 교통사고 현황 (사고유형별) 통계 데이터 | ⭐️⭐️ ||
# | 10   | 서울시 교통사고 현황 (사고유형별) 통계 + 서울시 차량통행속도 (구별/월별) 통계 + 서울시 인구밀도 (구별) 통계 | ⭐️⭐️⭐️ ||

# %% [markdown]
# ## 문제 소개 및 데이터 준비 단계
#
# <div style="border: 1px solid black; padding: 10px;">
#
# ### 문제 소개
# - 총 3단계 데이터 분석 상황 제시 (총 100점)
#     - 1단계 DataFrame 불러오기 & 전처리 (30점)
#     - 2단계 원하는 정보 얻기 (30점)
#     - 3단계 시각화 (40점)
#     - 시각화 단계는 채점 코드가 없습니다. 요구 조건에 맞는 그래프를 작성해주신 후 제출해주세요!
#
# ### Data 원본 출처
# - Source: [서울시 열린데이터](https://data.seoul.go.kr/dataList/419/S/2/datasetView.do)
# - Data Download: [PinkWink Blog](https://pinkwink.kr/attachment/cfile1.uf@99740C3A5ECB0EA52889B3.txt)
#
# ### 참고사항
# * 데이터는 탭으로 구분하여 TXT 파일 형식으로 제공
# * 외국인 세대수 제외
# * 65세이상 고령자 수: 외국인 포함
#
# </div>

# %%
 from grading import *

# %% [markdown]
# ## 문제 시작! 🏃🏻

# %% [markdown]
# ### 1단계: DataFrame 불러오기 & 전처리
# ***

# %% [markdown]
# ### **문제 1-1)** 0, 1, 2번 index의 row를 제거하고 index를 초기화 하세요(기존 index는 삭제(drop)하세요).    (10점)
#
# - 예시: 0,1,2번 index 제거
# <br></br>
#     <img src="images/01-1-1-001.png" style="margin:auto" width=130/>
#     <img src="images/01-1-1-002.png" style="margin:auto" width=180 height=180/>
#
# - 예시: index 초기화
# <br></br>
#     <img src="images/01-1-1-002.png" style="margin:auto" width=150/>
#     <img src="images/01-1-1-003.png" style="margin:auto" width=150/>
# <br></br>
# - 완료 후 결과 dataframe 변수를 check_01_01 함수에 입력하여 채점하세요.

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/report.txt',encoding='utf-8',sep='\t')
df.head(10)
# Out:
#          기간   자치구         세대          인구       인구.1       인구.2       인구.3  \
# 0        기간   자치구         세대          합계         합계         합계        한국인
# 1        기간   자치구         세대           계         남자         여자          계
# 2  2020.1/4    합계  4,354,006  10,013,781  4,874,995  5,138,786  9,733,655
# 3  2020.1/4   종로구     74,151     161,984     78,271     83,713    151,217
# 4  2020.1/4    중구     63,045     136,469     66,769     69,700    126,175
# 5  2020.1/4   용산구    110,895     246,165    119,961    126,204    229,579
# 6  2020.1/4   성동구    135,643     307,193    149,891    157,302    299,042
# 7  2020.1/4   광진구    165,287     365,990    176,226    189,764    350,417
# 8  2020.1/4  동대문구    165,279     362,793    178,202    184,591    346,156
# 9  2020.1/4   중랑구    182,220     400,678    198,122    202,556    395,619
#
#         인구.4       인구.5     인구.6     인구.7     인구.8  세대당인구   65세이상고령자
# 0        한국인        한국인    등록외국인    등록외국인    등록외국인  세대당인구   65세이상고령자
# 1         남자         여자        계       남자       여자  세대당인구   65세이상고령자
# 2  4,742,217  4,991,438  280,126  132,778  147,348   2.24  1,518,239
# 3     73,704     77,513   10,767    4,567    6,200   2.04     28,073
# 4     61,839     64,336   10,294    4,930    5,364      2     23,794
# 5    110,667    118,912   16,586    9,294    7,292   2.07     39,439
# 6    146,300    152,742    8,151    3,591    4,560    2.2     44,728
# 7    169,568    180,849   15,573    6,658    8,915   2.12     48,989
# 8    171,896    174,260   16,637    6,306   10,331   2.09     60,367
# 9    196,076    199,543    5,059    2,046    3,013   2.17     66,764

# %%
df.drop([0,1,2],axis=0,inplace=True)

# %%
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#           기간   자치구       세대       인구     인구.1     인구.2     인구.3     인구.4  \
# 0   2020.1/4   종로구   74,151  161,984   78,271   83,713  151,217   73,704
# 1   2020.1/4    중구   63,045  136,469   66,769   69,700  126,175   61,839
# 2   2020.1/4   용산구  110,895  246,165  119,961  126,204  229,579  110,667
# 3   2020.1/4   성동구  135,643  307,193  149,891  157,302  299,042  146,300
# 4   2020.1/4   광진구  165,287  365,990  176,226  189,764  350,417  169,568
# 5   2020.1/4  동대문구  165,279  362,793  178,202  184,591  346,156  171,896
# 6   2020.1/4   중랑구  182,220  400,678  198,122  202,556  395,619  196,076
# 7   2020.1/4   성북구  193,801  454,532  218,561  235,971  442,494  213,926
# 8   2020.1/4   강북구  144,805  316,750  154,141  162,609  312,985  152,747
# 9   2020.1/4   도봉구  138,595  333,495  162,774  170,721  331,238  161,879
# 10  2020.1/4   노원구  217,148  535,495  258,696  276,799  531,037  256,726
# 11  2020.1/4   은평구  208,209  482,509  231,953  250,556  478,019  230,147
# 12  2020.1/4  서대문구  142,109  325,875  154,502  171,373  312,642  150,051
# 13  2020.1/4   마포구  176,133  386,086  181,204  204,882  374,570  176,943
# 14  2020.1/4   양천구  177,436  460,532  226,109  234,423  456,339  224,241
# 15  2020.1/4   강서구  263,645  595,703  288,134  307,569  589,302  285,085
# 16  2020.1/4   구로구  177,275  438,308  218,970  219,338  405,837  200,558
# 17  2020.1/4   금천구  111,542  251,370  128,643  122,727  232,583  118,044
# 18  2020.1/4  영등포구  177,743  404,766  202,617  202,149  371,903  184,316
# 19  2020.1/4   동작구  181,761  407,802  196,943  210,859  395,014  191,272
# 20  2020.1/4   관악구  270,760  516,662  258,982  257,680  499,374  250,743
# 21  2020.1/4   서초구  173,580  434,801  207,877  226,924  430,568  205,787
# 22  2020.1/4   강남구  233,624  549,898  263,163  286,735  544,804  260,654
# 23  2020.1/4   송파구  279,301  680,883  329,058  351,825  674,095  325,859
# 24  2020.1/4   강동구  190,019  457,042  225,226  231,816  452,646  223,189
#
#        인구.5    인구.6    인구.7    인구.8 세대당인구 65세이상고령자
# 0    77,513  10,767   4,567   6,200  2.04   28,073
# 1    64,336  10,294   4,930   5,364     2   23,794
# 2   118,912  16,586   9,294   7,292  2.07   39,439
# 3   152,742   8,151   3,591   4,560   2.2   44,728
# 4   180,849  15,573   6,658   8,915  2.12   48,989
# 5   174,260  16,637   6,306  10,331  2.09   60,367
# 6   199,543   5,059   2,046   3,013  2.17   66,764
# 7   228,568  12,038   4,635   7,403  2.28   72,172
# 8   160,238   3,765   1,394   2,371  2.16   61,660
# 9   169,359   2,257     895   1,362  2.39   60,023
# 10  274,311   4,458   1,970   2,488  2.45   82,682
# 11  247,872   4,490   1,806   2,684   2.3   82,245
# 12  162,591  13,233   4,451   8,782   2.2   53,038
# 13  197,627  11,516   4,261   7,255  2.13   53,283
# 14  232,098   4,193   1,868   2,325  2.57   62,761
# 15  304,217   6,401   3,049   3,352  2.24   85,992
# 16  205,279  32,471  18,412  14,059  2.29   67,432
# 17  114,539  18,787  10,599   8,188  2.09   38,508
# 18  187,587  32,863  18,301  14,562  2.09   59,373
# 19  203,742  12,788   5,671   7,117  2.17   63,378
# 20  248,631  17,288   8,239   9,049  1.84   76,664
# 21  224,781   4,233   2,090   2,143  2.48   58,332
# 22  284,150   5,094   2,509   2,585  2.33   72,602
# 23  348,236   6,788   3,199   3,589  2.41   89,539
# 24  229,457   4,396   2,037   2,359  2.38   66,401

# %%
check_01_01(df)
# Out:
# 정답입니다! 10점 누적 되었습니다!
# 현재 누적 점수: 45 / 60

# %% [markdown]
# <h4 style="background-color:#9F81F7;color:#FBEFF2;font-weight:bold;display:inline-block;padding: 5px">채점 방법</h4>
#
# <div style="border: 1px solid black; padding: 10px;">
#
# 1. grading 모듈 불러오기
# ```python
#     from grading import *
# ```
# 2. 채점 코드 통과
# - 각 문제마다 번호에 맞는 채점 코드를 통과시켜주세요
#     - check_01_01(df), check_01_02(df) ...
# 3. 채점 코드까지 통과시킨 후, 제출!
#
# 사용 예시
# ```python
# check_01_01(df)
# 정답입니다! 10점 누적 되었습니다!
# 현재 누적 점수: 10 / 100
# ```
# </div>

# %%
 from grading import *

# %% [markdown]
# ### **문제 1-2)** 현재의 컬럼명(current_columns)을 아래 new_columns와 같이 변경하세요.      (10점)
#
# - current_columns = ['기간', '자치구', '세대', '인구', '인구.1', '인구.2', '인구.3', '인구.4', '인구.5', '인구.6', '인구.7', '인구.8', '세대당인구', '65세이상고령자']
# <br></br>
# - new_columns = ['기간', '자치구', '세대', '합계', '남자', '여자', '한국인 계', '한국인 남자', '한국인 여자', '등록외국인 계', '등록외국인 남자', '등록외국인 여자', '세대당인구', '65세이상고령자']
# <br></br>
# - 예시
# <br></br>
#     <img src="./images/01-1-2-001.png" style="margin:auto" width=150/>
#     <img src="./images/01-1-2-002.png" style="margin:auto" width=150/>
# <br></br>
# - 완료 후 결과 dataframe 변수를 check_01_02 함수에 입력하여 채점하세요.

# %%
current_columns = ['기간', '자치구', '세대', '인구', '인구.1', '인구.2', '인구.3', '인구.4', '인구.5', '인구.6', '인구.7', '인구.8', '세대당인구', '65세이상고령자']
new_columns = ['기간', '자치구', '세대', '합계', '남자', '여자', '한국인 계', '한국인 남자', '한국인 여자', '등록외국인 계', '등록외국인 남자', '등록외국인 여자', '세대당인구', '65세이상고령자']

# %%
for col in range(len(new_columns)):
    df.rename(columns={ current_columns[col] : new_columns[col] }, inplace=True )
df_target = df

# %%
# 1-2
check_01_02(df_target)
# Out:
# 정답입니다! 10점 누적 되었습니다!
# 현재 누적 점수: 45 / 60

# %%
df_target.tail()
# Out:
#           기간  자치구       세대       합계       남자       여자    한국인 계   한국인 남자  \
# 20  2020.1/4  관악구  270,760  516,662  258,982  257,680  499,374  250,743
# 21  2020.1/4  서초구  173,580  434,801  207,877  226,924  430,568  205,787
# 22  2020.1/4  강남구  233,624  549,898  263,163  286,735  544,804  260,654
# 23  2020.1/4  송파구  279,301  680,883  329,058  351,825  674,095  325,859
# 24  2020.1/4  강동구  190,019  457,042  225,226  231,816  452,646  223,189
#
#      한국인 여자 등록외국인 계 등록외국인 남자 등록외국인 여자 세대당인구 65세이상고령자
# 20  248,631  17,288    8,239    9,049  1.84   76,664
# 21  224,781   4,233    2,090    2,143  2.48   58,332
# 22  284,150   5,094    2,509    2,585  2.33   72,602
# 23  348,236   6,788    3,199    3,589  2.41   89,539
# 24  229,457   4,396    2,037    2,359  2.38   66,401

# %% [markdown]
# ### **문제 1-3)** 천단위 구분자 " , "를 제거하고, data의 type을 int 또는 float으로 변경하세요.   (10점)
# - 기간, 자치구: 변경 없음
# <br></br>
# - '세대', '합계', '남자', '여자', '한국인 계', '한국인 남자', '한국인 여자', '등록외국인 계', '등록외국인 남자', '등록외국인 여자', '65세이상고령자': 천단위 구분자 "," 제거 및 int로 타입 변경
# <br></br>
#     - 예시
# <br></br>
#     <img src="./images/01-1-3-001.png" style="margin:auto" width=150/>
#     <img src="./images/01-1-3-002.png" style="margin:auto" width=150/>
# <br></br>
# - '세대당인구': float으로 타입 변경
# <br></br>
#     - 예시
# <br></br>
#     <img src="./images/01-1-3-003.png" style="margin:auto" width=150/>
#     <img src="./images/01-1-3-004.png" style="margin:auto" width=150/>
# <br></br>
# - 완료 후 결과 dataframe 변수를 check_01_03 함수에 입력하여 채점하세요.

# %%
df_target.to_csv('../data/Eda_test.csv')

# %%
df_target = pd.read_csv('../data/Eda_test.csv',thousands=',',encoding='utf-8')

# %%
df_target.drop(columns='Unnamed: 0',inplace=True)

# %%
df_target.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   기간        25 non-null     object
#  1   자치구       25 non-null     object
#  2   세대        25 non-null     int64
#  3   합계        25 non-null     int64
#  4   남자        25 non-null     int64
#  5   여자        25 non-null     int64
#  6   한국인 계     25 non-null     int64
#  7   한국인 남자    25 non-null     int64
#  8   한국인 여자    25 non-null     int64
#  9   등록외국인 계   25 non-null     int64
#  10  등록외국인 남자  25 non-null     int64
#  11  등록외국인 여자  25 non-null     int64
#  12  세대당인구     25 non-null     float64
#  13  65세이상고령자  25 non-null     int64
# dtypes: float64(1), int64(11), object(2)
# memory usage: 2.9+ KB

# %%
# 1-3

check_01_03(df_target)
# Out:
# 정답입니다! 10점 누적 되었습니다!
# 현재 누적 점수: 55 / 60

# %%
df_target.tail()
# Out:
#           기간  자치구      세대      합계      남자      여자   한국인 계  한국인 남자  한국인 여자  \
# 20  2020.1/4  관악구  270760  516662  258982  257680  499374  250743  248631
# 21  2020.1/4  서초구  173580  434801  207877  226924  430568  205787  224781
# 22  2020.1/4  강남구  233624  549898  263163  286735  544804  260654  284150
# 23  2020.1/4  송파구  279301  680883  329058  351825  674095  325859  348236
# 24  2020.1/4  강동구  190019  457042  225226  231816  452646  223189  229457
#
#     등록외국인 계  등록외국인 남자  등록외국인 여자  세대당인구  65세이상고령자
# 20    17288      8239      9049   1.84     76664
# 21     4233      2090      2143   2.48     58332
# 22     5094      2509      2585   2.33     72602
# 23     6788      3199      3589   2.41     89539
# 24     4396      2037      2359   2.38     66401

# %% [markdown]
# ## 2단계: 원하는 정보 얻기

# %% [markdown]
# ### *Pandas DataFrame의 기능을 이용하여 아래 문제의 답을 구하세요.*
# ***
# #### 서울시는 아래와 같이 5개의 권역으로 구분됩니다.
# ![서울시 권역생활권](https://www.seoulsolution.kr/sites/default/files/images/%EC%B2%B4%EA%B3%846.jpg)
# - ref: [서울시-도시계획체계](https://www.seoulsolution.kr/ko/content/서울시-도시계획체계)
#
# - 도심권: ['종로구', '중구', '용산구']
# - 동북권: ['성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구', '도봉구', '노원구']
# - 서북권: ['은평구', '서대문구', '마포구']
# - 서남권: ['양천구', '강서구', '구로구', '금천구', '영등포구', '동작구', '관악구']
# - 동남권: ['서초구', '강남구', '송파구', '강동구']
# ***

# %%
region_dict = {'도심권': ['종로구', '중구', '용산구'],
               '동북권': ['성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구', '도봉구', '노원구'],
               '서북권': ['은평구', '서대문구', '마포구'],
               '서남권': ['양천구', '강서구', '구로구', '금천구', '영등포구', '동작구', '관악구'],
               '동남권': ['서초구', '강남구', '송파구', '강동구']
               }

# %%
region_dict['도심권'][0]
# Out:
# '종로구'

# %% [markdown]
# ### **문제 2-1)** 1단계에서 구한 DataFrame에 '권역' column을 추가하여 해당 구에 맞는 권역을 입력하세요.    (5점)
#
# - 예시
# <br></br>
#     <img src="./images/01-2-1-001.png" style="margin:auto" width=150/>
#     <img src="./images/01-2-1-002.png" style="margin:auto" width=200/>
#
# - 완료 후 결과 dataframe 변수를 check_02_01 함수에 입력하여 채점하세요.

# %%
df_target
# Out:
#           기간   자치구      세대      합계      남자      여자   한국인 계  한국인 남자  한국인 여자  \
# 0   2020.1/4   종로구   74151  161984   78271   83713  151217   73704   77513
# 1   2020.1/4    중구   63045  136469   66769   69700  126175   61839   64336
# 2   2020.1/4   용산구  110895  246165  119961  126204  229579  110667  118912
# 3   2020.1/4   성동구  135643  307193  149891  157302  299042  146300  152742
# 4   2020.1/4   광진구  165287  365990  176226  189764  350417  169568  180849
# 5   2020.1/4  동대문구  165279  362793  178202  184591  346156  171896  174260
# 6   2020.1/4   중랑구  182220  400678  198122  202556  395619  196076  199543
# 7   2020.1/4   성북구  193801  454532  218561  235971  442494  213926  228568
# 8   2020.1/4   강북구  144805  316750  154141  162609  312985  152747  160238
# 9   2020.1/4   도봉구  138595  333495  162774  170721  331238  161879  169359
# 10  2020.1/4   노원구  217148  535495  258696  276799  531037  256726  274311
# 11  2020.1/4   은평구  208209  482509  231953  250556  478019  230147  247872
# 12  2020.1/4  서대문구  142109  325875  154502  171373  312642  150051  162591
# 13  2020.1/4   마포구  176133  386086  181204  204882  374570  176943  197627
# 14  2020.1/4   양천구  177436  460532  226109  234423  456339  224241  232098
# 15  2020.1/4   강서구  263645  595703  288134  307569  589302  285085  304217
# 16  2020.1/4   구로구  177275  438308  218970  219338  405837  200558  205279
# 17  2020.1/4   금천구  111542  251370  128643  122727  232583  118044  114539
# 18  2020.1/4  영등포구  177743  404766  202617  202149  371903  184316  187587
# 19  2020.1/4   동작구  181761  407802  196943  210859  395014  191272  203742
# 20  2020.1/4   관악구  270760  516662  258982  257680  499374  250743  248631
# 21  2020.1/4   서초구  173580  434801  207877  226924  430568  205787  224781
# 22  2020.1/4   강남구  233624  549898  263163  286735  544804  260654  284150
# 23  2020.1/4   송파구  279301  680883  329058  351825  674095  325859  348236
# 24  2020.1/4   강동구  190019  457042  225226  231816  452646  223189  229457
#
#     등록외국인 계  등록외국인 남자  등록외국인 여자  세대당인구  65세이상고령자
# 0     10767      4567      6200   2.04     28073
# 1     10294      4930      5364   2.00     23794
# 2     16586      9294      7292   2.07     39439
# 3      8151      3591      4560   2.20     44728
# 4     15573      6658      8915   2.12     48989
# 5     16637      6306     10331   2.09     60367
# 6      5059      2046      3013   2.17     66764
# 7     12038      4635      7403   2.28     72172
# 8      3765      1394      2371   2.16     61660
# 9      2257       895      1362   2.39     60023
# 10     4458      1970      2488   2.45     82682
# 11     4490      1806      2684   2.30     82245
# 12    13233      4451      8782   2.20     53038
# 13    11516      4261      7255   2.13     53283
# 14     4193      1868      2325   2.57     62761
# 15     6401      3049      3352   2.24     85992
# 16    32471     18412     14059   2.29     67432
# 17    18787     10599      8188   2.09     38508
# 18    32863     18301     14562   2.09     59373
# 19    12788      5671      7117   2.17     63378
# 20    17288      8239      9049   1.84     76664
# 21     4233      2090      2143   2.48     58332
# 22     5094      2509      2585   2.33     72602
# 23     6788      3199      3589   2.41     89539
# 24     4396      2037      2359   2.38     66401

# %%
for idx,row in df.iterrows():
    for r in region_dict.keys():
        if row['자치구'] in region_dict[r]:
            df_target.loc[idx,'권역'] = r

# %%
df_target
# Out:
#           기간   자치구      세대      합계      남자      여자   한국인 계  한국인 남자  한국인 여자  \
# 0   2020.1/4   종로구   74151  161984   78271   83713  151217   73704   77513
# 1   2020.1/4    중구   63045  136469   66769   69700  126175   61839   64336
# 2   2020.1/4   용산구  110895  246165  119961  126204  229579  110667  118912
# 3   2020.1/4   성동구  135643  307193  149891  157302  299042  146300  152742
# 4   2020.1/4   광진구  165287  365990  176226  189764  350417  169568  180849
# 5   2020.1/4  동대문구  165279  362793  178202  184591  346156  171896  174260
# 6   2020.1/4   중랑구  182220  400678  198122  202556  395619  196076  199543
# 7   2020.1/4   성북구  193801  454532  218561  235971  442494  213926  228568
# 8   2020.1/4   강북구  144805  316750  154141  162609  312985  152747  160238
# 9   2020.1/4   도봉구  138595  333495  162774  170721  331238  161879  169359
# 10  2020.1/4   노원구  217148  535495  258696  276799  531037  256726  274311
# 11  2020.1/4   은평구  208209  482509  231953  250556  478019  230147  247872
# 12  2020.1/4  서대문구  142109  325875  154502  171373  312642  150051  162591
# 13  2020.1/4   마포구  176133  386086  181204  204882  374570  176943  197627
# 14  2020.1/4   양천구  177436  460532  226109  234423  456339  224241  232098
# 15  2020.1/4   강서구  263645  595703  288134  307569  589302  285085  304217
# 16  2020.1/4   구로구  177275  438308  218970  219338  405837  200558  205279
# 17  2020.1/4   금천구  111542  251370  128643  122727  232583  118044  114539
# 18  2020.1/4  영등포구  177743  404766  202617  202149  371903  184316  187587
# 19  2020.1/4   동작구  181761  407802  196943  210859  395014  191272  203742
# 20  2020.1/4   관악구  270760  516662  258982  257680  499374  250743  248631
# 21  2020.1/4   서초구  173580  434801  207877  226924  430568  205787  224781
# 22  2020.1/4   강남구  233624  549898  263163  286735  544804  260654  284150
# 23  2020.1/4   송파구  279301  680883  329058  351825  674095  325859  348236
# 24  2020.1/4   강동구  190019  457042  225226  231816  452646  223189  229457
#
#     등록외국인 계  등록외국인 남자  등록외국인 여자  세대당인구  65세이상고령자   권역
# 0     10767      4567      6200   2.04     28073  도심권
# 1     10294      4930      5364   2.00     23794  도심권
# 2     16586      9294      7292   2.07     39439  도심권
# 3      8151      3591      4560   2.20     44728  동북권
# 4     15573      6658      8915   2.12     48989  동북권
# 5     16637      6306     10331   2.09     60367  동북권
# 6      5059      2046      3013   2.17     66764  동북권
# 7     12038      4635      7403   2.28     72172  동북권
# 8      3765      1394      2371   2.16     61660  동북권
# 9      2257       895      1362   2.39     60023  동북권
# 10     4458      1970      2488   2.45     82682  동북권
# 11     4490      1806      2684   2.30     82245  서북권
# 12    13233      4451      8782   2.20     53038  서북권
# 13    11516      4261      7255   2.13     53283  서북권
# 14     4193      1868      2325   2.57     62761  서남권
# 15     6401      3049      3352   2.24     85992  서남권
# 16    32471     18412     14059   2.29     67432  서남권
# 17    18787     10599      8188   2.09     38508  서남권
# 18    32863     18301     14562   2.09     59373  서남권
# 19    12788      5671      7117   2.17     63378  서남권
# 20    17288      8239      9049   1.84     76664  서남권
# 21     4233      2090      2143   2.48     58332  동남권
# 22     5094      2509      2585   2.33     72602  동남권
# 23     6788      3199      3589   2.41     89539  동남권
# 24     4396      2037      2359   2.38     66401  동남권

# %%
df_target['권역'].unique()
# Out:
# array(['도심권', '동북권', '서북권', '서남권', '동남권'], dtype=object)

# %%
# 2-1

check_02_01(df_target)
# Out:
# 정답입니다! 5점 누적 되었습니다!
# 현재 누적 점수: 60 / 60

# %% [markdown]
# ### **문제 2-2)** 2-1에서 만든 DataFrame을 이용하여 Pandas의 pivot_table 메소드를 활용하여 각 권역별 아래 값의 합을 구하고, '합계'를 기준으로 내림차순 정렬하세요.      (5점)
#
# - 구할 값: ['합계', '세대', '여자', '한국인 계', '등록외국인 계', '65세이상고령자']
#
# - 참고: [Pivot Table](https://pandas.pydata.org/docs/reference/api/pandas.pivot_table.html)
# <br></br>
#     - 예시
# <br></br>
#     <img src="./images/01-2-2-001.png" style="margin:auto" width=150/>
#     <img src="./images/01-2-2-002.png" style="margin:auto" width=150/>
# <br></br>
# - 완료 후 결과 dataframe 변수를 check_02_02 함수에 입력하여 채점하세요.

# %%
df_target.head()
# Out:
#          기간  자치구      세대      합계      남자      여자   한국인 계  한국인 남자  한국인 여자  \
# 0  2020.1/4  종로구   74151  161984   78271   83713  151217   73704   77513
# 1  2020.1/4   중구   63045  136469   66769   69700  126175   61839   64336
# 2  2020.1/4  용산구  110895  246165  119961  126204  229579  110667  118912
# 3  2020.1/4  성동구  135643  307193  149891  157302  299042  146300  152742
# 4  2020.1/4  광진구  165287  365990  176226  189764  350417  169568  180849
#
#    등록외국인 계  등록외국인 남자  등록외국인 여자  세대당인구  65세이상고령자   권역
# 0    10767      4567      6200   2.04     28073  도심권
# 1    10294      4930      5364   2.00     23794  도심권
# 2    16586      9294      7292   2.07     39439  도심권
# 3     8151      3591      4560   2.20     44728  동북권
# 4    15573      6658      8915   2.12     48989  동북권

# %%
import numpy as np

# %%
df_pivot= df_target.pivot_table(index='권역',values=['합계', '세대', '여자', '한국인 계', '등록외국인 계', '65세이상고령자'],aggfunc=np.sum)

# %%
df_pivot
# Out:
#      65세이상고령자  등록외국인 계       세대       여자    한국인 계       합계
# 권역
# 도심권     91306    37647   248091   279617   506971   544618
# 동남권    286874    20511   876524  1097300  2102113  2122624
# 동북권    497385    67938  1342778  1580313  3008988  3076926
# 서남권    454108   124791  1360162  1554745  2950352  3075143
# 서북권    188566    29239   526451   626811  1165231  1194470

# %%
df_pivot=df_pivot.sort_values(by='합계',ascending=False)

# %%
# 2-2

check_02_02(df_pivot)
# Out:
# 정답입니다! 5점 누적 되었습니다!
# 현재 누적 점수: 60 / 60

# %%
df_pivot
# Out:
#      65세이상고령자  등록외국인 계       세대       여자    한국인 계       합계
# 권역
# 동북권    497385    67938  1342778  1580313  3008988  3076926
# 서남권    454108   124791  1360162  1554745  2950352  3075143
# 동남권    286874    20511   876524  1097300  2102113  2122624
# 서북권    188566    29239   526451   626811  1165231  1194470
# 도심권     91306    37647   248091   279617   506971   544618

# %% [markdown]
# ### **문제 2-3)** 2-2에서 만든 Pivot Table을 이용하여 각 권역별 ['고령자비율', '외국인비율', '여성비율', '세대당인구'] 컬럼을 만들어 아래와 같이 값을 입력하고 '외국인비율'을 기준으로 오름차순 정렬하세요.  (5점)
#
# - 고령자비율: 65세이상고령자 / 합계 * 100
#
# - 외국인비율: 등록외국인 계 / 합계 * 100
#
# - 여성비율: 여자 / 합계 * 100
#
# - 세대당인구: (합계 - 등록외국인 계) / 세대
# <br></br>
# - 예시: B/C 비율 및  B 기준 오름차순 정렬
# <br></br>
#     <img src="./images/01-2-2-002.png" style="margin:auto" width=150/>
#     <img src="./images/01-2-3-001.png" style="margin:auto" width=230/>
# <br></br>
# - 완료 후 결과 dataframe 변수를 check_02_03 함수에 입력하여 채점하세요.

# %%
df_pivot[['고령자비율', '외국인비율', '여성비율', '세대당인구']] = np.nan

# %%
df_pivot
# Out:
#      65세이상고령자  등록외국인 계       세대       여자    한국인 계       합계  고령자비율  외국인비율  \
# 권역
# 동북권    497385    67938  1342778  1580313  3008988  3076926    NaN    NaN
# 서남권    454108   124791  1360162  1554745  2950352  3075143    NaN    NaN
# 동남권    286874    20511   876524  1097300  2102113  2122624    NaN    NaN
# 서북권    188566    29239   526451   626811  1165231  1194470    NaN    NaN
# 도심권     91306    37647   248091   279617   506971   544618    NaN    NaN
#
#      여성비율  세대당인구
# 권역
# 동북권   NaN    NaN
# 서남권   NaN    NaN
# 동남권   NaN    NaN
# 서북권   NaN    NaN
# 도심권   NaN    NaN

# %%
df_pivot['고령자비율']= (df_pivot['65세이상고령자'].div(df_pivot['합계'].values,axis=0)) * 100

# %%
df_pivot
# Out:
#      65세이상고령자  등록외국인 계       세대       여자    한국인 계       합계      고령자비율  외국인비율  \
# 권역
# 동북권    497385    67938  1342778  1580313  3008988  3076926  16.164997    NaN
# 서남권    454108   124791  1360162  1554745  2950352  3075143  14.767053    NaN
# 동남권    286874    20511   876524  1097300  2102113  2122624  13.515064    NaN
# 서북권    188566    29239   526451   626811  1165231  1194470  15.786583    NaN
# 도심권     91306    37647   248091   279617   506971   544618  16.765145    NaN
#
#      여성비율  세대당인구
# 권역
# 동북권   NaN    NaN
# 서남권   NaN    NaN
# 동남권   NaN    NaN
# 서북권   NaN    NaN
# 도심권   NaN    NaN

# %%
df_pivot['외국인비율']= (df_pivot['등록외국인 계'].div(df_pivot['합계'].values,axis=0)) * 100

# %%
df_pivot
# Out:
#      65세이상고령자  등록외국인 계       세대       여자    한국인 계       합계      고령자비율  \
# 권역
# 동북권    497385    67938  1342778  1580313  3008988  3076926  16.164997
# 서남권    454108   124791  1360162  1554745  2950352  3075143  14.767053
# 동남권    286874    20511   876524  1097300  2102113  2122624  13.515064
# 서북권    188566    29239   526451   626811  1165231  1194470  15.786583
# 도심권     91306    37647   248091   279617   506971   544618  16.765145
#
#         외국인비율  여성비율  세대당인구
# 권역
# 동북권  2.207983   NaN    NaN
# 서남권  4.058055   NaN    NaN
# 동남권  0.966304   NaN    NaN
# 서북권  2.447864   NaN    NaN
# 도심권  6.912552   NaN    NaN

# %%
df_pivot['여성비율']= df_pivot['여자'].div(df_pivot['합계'].values,axis=0) * 100

# %%
df_pivot
# Out:
#      65세이상고령자  등록외국인 계       세대       여자    한국인 계       합계      고령자비율  \
# 권역
# 동북권    497385    67938  1342778  1580313  3008988  3076926  16.164997
# 서남권    454108   124791  1360162  1554745  2950352  3075143  14.767053
# 동남권    286874    20511   876524  1097300  2102113  2122624  13.515064
# 서북권    188566    29239   526451   626811  1165231  1194470  15.786583
# 도심권     91306    37647   248091   279617   506971   544618  16.765145
#
#         외국인비율       여성비율  세대당인구
# 권역
# 동북권  2.207983  51.360124    NaN
# 서남권  4.058055  50.558462    NaN
# 동남권  0.966304  51.695449    NaN
# 서북권  2.447864  52.476077    NaN
# 도심권  6.912552  51.341858    NaN

# %%
df_pivot['세대당인구']= (df_pivot['합계']-df_pivot['등록외국인 계']) / df_pivot['세대']

# %%
df_pivot
# Out:
#      65세이상고령자  등록외국인 계       세대       여자    한국인 계       합계      고령자비율  \
# 권역
# 동북권    497385    67938  1342778  1580313  3008988  3076926  16.164997
# 서남권    454108   124791  1360162  1554745  2950352  3075143  14.767053
# 동남권    286874    20511   876524  1097300  2102113  2122624  13.515064
# 서북권    188566    29239   526451   626811  1165231  1194470  15.786583
# 도심권     91306    37647   248091   279617   506971   544618  16.765145
#
#         외국인비율       여성비율     세대당인구
# 권역
# 동북권  2.207983  51.360124  2.240868
# 서남권  4.058055  50.558462  2.169118
# 동남권  0.966304  51.695449  2.398238
# 서북권  2.447864  52.476077  2.213370
# 도심권  6.912552  51.341858  2.043488

# %%
df_pivot = df_pivot.sort_values(by='외국인비율')

# %%
df_pivot
# Out:
#      65세이상고령자  등록외국인 계       세대       여자    한국인 계       합계      고령자비율  \
# 권역
# 동남권    286874    20511   876524  1097300  2102113  2122624  13.515064
# 동북권    497385    67938  1342778  1580313  3008988  3076926  16.164997
# 서북권    188566    29239   526451   626811  1165231  1194470  15.786583
# 서남권    454108   124791  1360162  1554745  2950352  3075143  14.767053
# 도심권     91306    37647   248091   279617   506971   544618  16.765145
#
#         외국인비율       여성비율     세대당인구
# 권역
# 동남권  0.966304  51.695449  2.398238
# 동북권  2.207983  51.360124  2.240868
# 서북권  2.447864  52.476077  2.213370
# 서남권  4.058055  50.558462  2.169118
# 도심권  6.912552  51.341858  2.043488

# %%
# 2-3

check_02_03(df_pivot)
# Out:
# 정답입니다! 5점 누적 되었습니다!
# 현재 누적 점수: 60 / 60

# %%
df_pivot
# Out:
#      65세이상고령자  등록외국인 계       세대       여자    한국인 계       합계      고령자비율  \
# 권역
# 동남권    286874    20511   876524  1097300  2102113  2122624  13.515064
# 동북권    497385    67938  1342778  1580313  3008988  3076926  16.164997
# 서북권    188566    29239   526451   626811  1165231  1194470  15.786583
# 서남권    454108   124791  1360162  1554745  2950352  3075143  14.767053
# 도심권     91306    37647   248091   279617   506971   544618  16.765145
#
#         외국인비율       여성비율     세대당인구
# 권역
# 동남권  0.966304  51.695449  2.398238
# 동북권  2.207983  51.360124  2.240868
# 서북권  2.447864  52.476077  2.213370
# 서남권  4.058055  50.558462  2.169118
# 도심권  6.912552  51.341858  2.043488

# %% [markdown]
# ### **문제 2-4)** 2-1에서 만든 DataFrame을 이용하여 각 구별 ['고령자비율', '외국인비율', '여성비율'] 컬럼을 만들어 아래와 같이 값을 입력하고 '세대당인구'을 기준으로 내림차순 정렬하세요.  (5점)
# - 고령자비율: 65세이상고령자 / 합계 * 100
# - 외국인비율: 등록외국인 계 / 합계 * 100
# - 여성비율: 여자 / 합계 * 100
# - 완료 후 결과 dataframe 변수를 check_02_04 함수에 입력하여 채점하세요.

# %%
df_target
# Out:
#           기간   자치구      세대      합계      남자      여자   한국인 계  한국인 남자  한국인 여자  \
# 0   2020.1/4   종로구   74151  161984   78271   83713  151217   73704   77513
# 1   2020.1/4    중구   63045  136469   66769   69700  126175   61839   64336
# 2   2020.1/4   용산구  110895  246165  119961  126204  229579  110667  118912
# 3   2020.1/4   성동구  135643  307193  149891  157302  299042  146300  152742
# 4   2020.1/4   광진구  165287  365990  176226  189764  350417  169568  180849
# 5   2020.1/4  동대문구  165279  362793  178202  184591  346156  171896  174260
# 6   2020.1/4   중랑구  182220  400678  198122  202556  395619  196076  199543
# 7   2020.1/4   성북구  193801  454532  218561  235971  442494  213926  228568
# 8   2020.1/4   강북구  144805  316750  154141  162609  312985  152747  160238
# 9   2020.1/4   도봉구  138595  333495  162774  170721  331238  161879  169359
# 10  2020.1/4   노원구  217148  535495  258696  276799  531037  256726  274311
# 11  2020.1/4   은평구  208209  482509  231953  250556  478019  230147  247872
# 12  2020.1/4  서대문구  142109  325875  154502  171373  312642  150051  162591
# 13  2020.1/4   마포구  176133  386086  181204  204882  374570  176943  197627
# 14  2020.1/4   양천구  177436  460532  226109  234423  456339  224241  232098
# 15  2020.1/4   강서구  263645  595703  288134  307569  589302  285085  304217
# 16  2020.1/4   구로구  177275  438308  218970  219338  405837  200558  205279
# 17  2020.1/4   금천구  111542  251370  128643  122727  232583  118044  114539
# 18  2020.1/4  영등포구  177743  404766  202617  202149  371903  184316  187587
# 19  2020.1/4   동작구  181761  407802  196943  210859  395014  191272  203742
# 20  2020.1/4   관악구  270760  516662  258982  257680  499374  250743  248631
# 21  2020.1/4   서초구  173580  434801  207877  226924  430568  205787  224781
# 22  2020.1/4   강남구  233624  549898  263163  286735  544804  260654  284150
# 23  2020.1/4   송파구  279301  680883  329058  351825  674095  325859  348236
# 24  2020.1/4   강동구  190019  457042  225226  231816  452646  223189  229457
#
#     등록외국인 계  등록외국인 남자  등록외국인 여자  세대당인구  65세이상고령자   권역
# 0     10767      4567      6200   2.04     28073  도심권
# 1     10294      4930      5364   2.00     23794  도심권
# 2     16586      9294      7292   2.07     39439  도심권
# 3      8151      3591      4560   2.20     44728  동북권
# 4     15573      6658      8915   2.12     48989  동북권
# 5     16637      6306     10331   2.09     60367  동북권
# 6      5059      2046      3013   2.17     66764  동북권
# 7     12038      4635      7403   2.28     72172  동북권
# 8      3765      1394      2371   2.16     61660  동북권
# 9      2257       895      1362   2.39     60023  동북권
# 10     4458      1970      2488   2.45     82682  동북권
# 11     4490      1806      2684   2.30     82245  서북권
# 12    13233      4451      8782   2.20     53038  서북권
# 13    11516      4261      7255   2.13     53283  서북권
# 14     4193      1868      2325   2.57     62761  서남권
# 15     6401      3049      3352   2.24     85992  서남권
# 16    32471     18412     14059   2.29     67432  서남권
# 17    18787     10599      8188   2.09     38508  서남권
# 18    32863     18301     14562   2.09     59373  서남권
# 19    12788      5671      7117   2.17     63378  서남권
# 20    17288      8239      9049   1.84     76664  서남권
# 21     4233      2090      2143   2.48     58332  동남권
# 22     5094      2509      2585   2.33     72602  동남권
# 23     6788      3199      3589   2.41     89539  동남권
# 24     4396      2037      2359   2.38     66401  동남권

# %%
df_target[ ['고령자비율', '외국인비율', '여성비율'] ] =np.nan

# %%
df_target
# Out:
#           기간   자치구      세대      합계      남자      여자   한국인 계  한국인 남자  한국인 여자  \
# 0   2020.1/4   종로구   74151  161984   78271   83713  151217   73704   77513
# 1   2020.1/4    중구   63045  136469   66769   69700  126175   61839   64336
# 2   2020.1/4   용산구  110895  246165  119961  126204  229579  110667  118912
# 3   2020.1/4   성동구  135643  307193  149891  157302  299042  146300  152742
# 4   2020.1/4   광진구  165287  365990  176226  189764  350417  169568  180849
# 5   2020.1/4  동대문구  165279  362793  178202  184591  346156  171896  174260
# 6   2020.1/4   중랑구  182220  400678  198122  202556  395619  196076  199543
# 7   2020.1/4   성북구  193801  454532  218561  235971  442494  213926  228568
# 8   2020.1/4   강북구  144805  316750  154141  162609  312985  152747  160238
# 9   2020.1/4   도봉구  138595  333495  162774  170721  331238  161879  169359
# 10  2020.1/4   노원구  217148  535495  258696  276799  531037  256726  274311
# 11  2020.1/4   은평구  208209  482509  231953  250556  478019  230147  247872
# 12  2020.1/4  서대문구  142109  325875  154502  171373  312642  150051  162591
# 13  2020.1/4   마포구  176133  386086  181204  204882  374570  176943  197627
# 14  2020.1/4   양천구  177436  460532  226109  234423  456339  224241  232098
# 15  2020.1/4   강서구  263645  595703  288134  307569  589302  285085  304217
# 16  2020.1/4   구로구  177275  438308  218970  219338  405837  200558  205279
# 17  2020.1/4   금천구  111542  251370  128643  122727  232583  118044  114539
# 18  2020.1/4  영등포구  177743  404766  202617  202149  371903  184316  187587
# 19  2020.1/4   동작구  181761  407802  196943  210859  395014  191272  203742
# 20  2020.1/4   관악구  270760  516662  258982  257680  499374  250743  248631
# 21  2020.1/4   서초구  173580  434801  207877  226924  430568  205787  224781
# 22  2020.1/4   강남구  233624  549898  263163  286735  544804  260654  284150
# 23  2020.1/4   송파구  279301  680883  329058  351825  674095  325859  348236
# 24  2020.1/4   강동구  190019  457042  225226  231816  452646  223189  229457
#
#     등록외국인 계  등록외국인 남자  등록외국인 여자  세대당인구  65세이상고령자   권역  고령자비율  외국인비율  여성비율
# 0     10767      4567      6200   2.04     28073  도심권    NaN    NaN   NaN
# 1     10294      4930      5364   2.00     23794  도심권    NaN    NaN   NaN
# 2     16586      9294      7292   2.07     39439  도심권    NaN    NaN   NaN
# 3      8151      3591      4560   2.20     44728  동북권    NaN    NaN   NaN
# 4     15573      6658      8915   2.12     48989  동북권    NaN    NaN   NaN
# 5     16637      6306     10331   2.09     60367  동북권    NaN    NaN   NaN
# 6      5059      2046      3013   2.17     66764  동북권    NaN    NaN   NaN
# 7     12038      4635      7403   2.28     72172  동북권    NaN    NaN   NaN
# 8      3765      1394      2371   2.16     61660  동북권    NaN    NaN   NaN
# 9      2257       895      1362   2.39     60023  동북권    NaN    NaN   NaN
# 10     4458      1970      2488   2.45     82682  동북권    NaN    NaN   NaN
# 11     4490      1806      2684   2.30     82245  서북권    NaN    NaN   NaN
# 12    13233      4451      8782   2.20     53038  서북권    NaN    NaN   NaN
# 13    11516      4261      7255   2.13     53283  서북권    NaN    NaN   NaN
# 14     4193      1868      2325   2.57     62761  서남권    NaN    NaN   NaN
# 15     6401      3049      3352   2.24     85992  서남권    NaN    NaN   NaN
# 16    32471     18412     14059   2.29     67432  서남권    NaN    NaN   NaN
# 17    18787     10599      8188   2.09     38508  서남권    NaN    NaN   NaN
# 18    32863     18301     14562   2.09     59373  서남권    NaN    NaN   NaN
# 19    12788      5671      7117   2.17     63378  서남권    NaN    NaN   NaN
# 20    17288      8239      9049   1.84     76664  서남권    NaN    NaN   NaN
# 21     4233      2090      2143   2.48     58332  동남권    NaN    NaN   NaN
# 22     5094      2509      2585   2.33     72602  동남권    NaN    NaN   NaN
# 23     6788      3199      3589   2.41     89539  동남권    NaN    NaN   NaN
# 24     4396      2037      2359   2.38     66401  동남권    NaN    NaN   NaN

# %%
df_target['고령자비율'] = df_target['65세이상고령자'].div(df_target['합계'].values,axis=0) *100

# %%
df_target.head()
# Out:
#          기간  자치구      세대      합계      남자      여자   한국인 계  한국인 남자  한국인 여자  \
# 0  2020.1/4  종로구   74151  161984   78271   83713  151217   73704   77513
# 1  2020.1/4   중구   63045  136469   66769   69700  126175   61839   64336
# 2  2020.1/4  용산구  110895  246165  119961  126204  229579  110667  118912
# 3  2020.1/4  성동구  135643  307193  149891  157302  299042  146300  152742
# 4  2020.1/4  광진구  165287  365990  176226  189764  350417  169568  180849
#
#    등록외국인 계  등록외국인 남자  등록외국인 여자  세대당인구  65세이상고령자   권역      고령자비율  외국인비율  여성비율
# 0    10767      4567      6200   2.04     28073  도심권  17.330724    NaN   NaN
# 1    10294      4930      5364   2.00     23794  도심권  17.435462    NaN   NaN
# 2    16586      9294      7292   2.07     39439  도심권  16.021368    NaN   NaN
# 3     8151      3591      4560   2.20     44728  동북권  14.560228    NaN   NaN
# 4    15573      6658      8915   2.12     48989  동북권  13.385338    NaN   NaN

# %%
df_target['외국인비율'] = df_target['등록외국인 계'].div(df_target['합계'].values,axis=0) *100

# %%
df_target.head()
# Out:
#          기간  자치구      세대      합계      남자      여자   한국인 계  한국인 남자  한국인 여자  \
# 0  2020.1/4  종로구   74151  161984   78271   83713  151217   73704   77513
# 1  2020.1/4   중구   63045  136469   66769   69700  126175   61839   64336
# 2  2020.1/4  용산구  110895  246165  119961  126204  229579  110667  118912
# 3  2020.1/4  성동구  135643  307193  149891  157302  299042  146300  152742
# 4  2020.1/4  광진구  165287  365990  176226  189764  350417  169568  180849
#
#    등록외국인 계  등록외국인 남자  등록외국인 여자  세대당인구  65세이상고령자   권역      고령자비율     외국인비율  \
# 0    10767      4567      6200   2.04     28073  도심권  17.330724  6.646953
# 1    10294      4930      5364   2.00     23794  도심권  17.435462  7.543105
# 2    16586      9294      7292   2.07     39439  도심권  16.021368  6.737757
# 3     8151      3591      4560   2.20     44728  동북권  14.560228  2.653381
# 4    15573      6658      8915   2.12     48989  동북권  13.385338  4.255034
#
#    여성비율
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN

# %%
df_target['여성비율'] = df_target['여자'].div(df_target['합계'].values,axis=0) *100

# %%
df_target.head()
# Out:
#          기간  자치구      세대      합계      남자      여자   한국인 계  한국인 남자  한국인 여자  \
# 0  2020.1/4  종로구   74151  161984   78271   83713  151217   73704   77513
# 1  2020.1/4   중구   63045  136469   66769   69700  126175   61839   64336
# 2  2020.1/4  용산구  110895  246165  119961  126204  229579  110667  118912
# 3  2020.1/4  성동구  135643  307193  149891  157302  299042  146300  152742
# 4  2020.1/4  광진구  165287  365990  176226  189764  350417  169568  180849
#
#    등록외국인 계  등록외국인 남자  등록외국인 여자  세대당인구  65세이상고령자   권역      고령자비율     외국인비율  \
# 0    10767      4567      6200   2.04     28073  도심권  17.330724  6.646953
# 1    10294      4930      5364   2.00     23794  도심권  17.435462  7.543105
# 2    16586      9294      7292   2.07     39439  도심권  16.021368  6.737757
# 3     8151      3591      4560   2.20     44728  동북권  14.560228  2.653381
# 4    15573      6658      8915   2.12     48989  동북권  13.385338  4.255034
#
#         여성비율
# 0  51.679796
# 1  51.073870
# 2  51.268052
# 3  51.206245
# 4  51.849504

# %%
df_target = df_target.sort_values(by='세대당인구',ascending=False)

# %%
df_target.head()
# Out:
#           기간  자치구      세대      합계      남자      여자   한국인 계  한국인 남자  한국인 여자  \
# 14  2020.1/4  양천구  177436  460532  226109  234423  456339  224241  232098
# 21  2020.1/4  서초구  173580  434801  207877  226924  430568  205787  224781
# 10  2020.1/4  노원구  217148  535495  258696  276799  531037  256726  274311
# 23  2020.1/4  송파구  279301  680883  329058  351825  674095  325859  348236
# 9   2020.1/4  도봉구  138595  333495  162774  170721  331238  161879  169359
#
#     등록외국인 계  등록외국인 남자  등록외국인 여자  세대당인구  65세이상고령자   권역      고령자비율     외국인비율  \
# 14     4193      1868      2325   2.57     62761  서남권  13.627935  0.910469
# 21     4233      2090      2143   2.48     58332  동남권  13.415793  0.973549
# 10     4458      1970      2488   2.45     82682  동북권  15.440294  0.832501
# 23     6788      3199      3589   2.41     89539  동남권  13.150424  0.996941
# 9      2257       895      1362   2.39     60023  동북권  17.998171  0.676772
#
#          여성비율
# 14  50.902652
# 21  52.190312
# 10  51.690305
# 23  51.671873
# 9   51.191472

# %%
# 2-4

check_02_04(df_target)
# Out:
# 정답입니다! 5점 누적 되었습니다!
# 현재 누적 점수: 60 / 60

# %%
df_target.tail(2)
# Out:
#           기간  자치구      세대      합계      남자      여자   한국인 계  한국인 남자  한국인 여자  \
# 1   2020.1/4   중구   63045  136469   66769   69700  126175   61839   64336
# 20  2020.1/4  관악구  270760  516662  258982  257680  499374  250743  248631
#
#     등록외국인 계  등록외국인 남자  등록외국인 여자  세대당인구  65세이상고령자   권역      고령자비율     외국인비율  \
# 1     10294      4930      5364   2.00     23794  도심권  17.435462  7.543105
# 20    17288      8239      9049   1.84     76664  서남권  14.838328  3.346095
#
#          여성비율
# 1   51.073870
# 20  49.873999

# %% [markdown]
# ### **문제 2-5)** 2-3에서 만든 DataFrame을 이용하여 ['고령자비율', '외국인비율', '여성비율', '세대당인구']간의 피어슨 상관계수 행렬(Correlation matrix)를 구하세요. (10점)
#
# - 참고
#     - 상관계수(correlation coefficient): 두 변수가 함께 변하는 정도를 -1 ~ +1 범위의 수로 나타낸 것
#
#     - 피어슨 상관계수: 칼 피어슨(Karl Pearson)이 개발한 상관계수로, 일반적으로 상관계수라고 하면 피어슨 상관계수를 말함
#         - Standard Correlation Coefficient
#         - r(상관계수) = X와 Y가 함께 변하는 정도 / X와 Y가 각각 변하는 정도
# <br></br>
#     - 상관계수 행렬(Correlation Matrix): 변수간 상관계수를 보여주는 행렬
# <br></br>
#         - 예시: dog와 cat간의 상관계수 행렬
# <br></br>
#         <img src='./images/01-2-5-001.png' width=150>
#         <img src='./images/01-2-5-002.png' width=350>
# <br></br>
# - 완료 후 결과 dataframe 변수를 check_02_05 함수에 입력하여 채점하세요.

# %%
df_pivot
# Out:
#      65세이상고령자  등록외국인 계       세대       여자    한국인 계       합계      고령자비율  \
# 권역
# 동남권    286874    20511   876524  1097300  2102113  2122624  13.515064
# 동북권    497385    67938  1342778  1580313  3008988  3076926  16.164997
# 서북권    188566    29239   526451   626811  1165231  1194470  15.786583
# 서남권    454108   124791  1360162  1554745  2950352  3075143  14.767053
# 도심권     91306    37647   248091   279617   506971   544618  16.765145
#
#         외국인비율       여성비율     세대당인구
# 권역
# 동남권  0.966304  51.695449  2.398238
# 동북권  2.207983  51.360124  2.240868
# 서북권  2.447864  52.476077  2.213370
# 서남권  4.058055  50.558462  2.169118
# 도심권  6.912552  51.341858  2.043488

# %%
pivot_corr = df_pivot.corr()

# %%
pivot_corr
# Out:
#           65세이상고령자   등록외국인 계        세대        여자     한국인 계        합계  \
# 65세이상고령자  1.000000  0.692541  0.993002  0.989734  0.988591  0.989624
# 등록외국인 계   0.692541  1.000000  0.715982  0.668665  0.662168  0.682990
# 세대        0.993002  0.715982  1.000000  0.997588  0.996803  0.998509
# 여자        0.989734  0.668665  0.997588  1.000000  0.999930  0.999780
# 한국인 계     0.988591  0.662168  0.996803  0.999930  1.000000  0.999604
# 합계        0.989624  0.682990  0.998509  0.999780  0.999604  1.000000
# 고령자비율    -0.283126 -0.013428 -0.374200 -0.416096 -0.423040 -0.412858
# 외국인비율    -0.460678  0.201942 -0.468845 -0.520445 -0.525378 -0.504525
# 여성비율     -0.524995 -0.822037 -0.559553 -0.525376 -0.523968 -0.541599
# 세대당인구     0.358033 -0.283314  0.388999  0.449461  0.457387  0.435196
#
#              고령자비율     외국인비율      여성비율     세대당인구
# 65세이상고령자 -0.283126 -0.460678 -0.524995  0.358033
# 등록외국인 계  -0.013428  0.201942 -0.822037 -0.283314
# 세대       -0.374200 -0.468845 -0.559553  0.388999
# 여자       -0.416096 -0.520445 -0.525376  0.449461
# 한국인 계    -0.423040 -0.525378 -0.523968  0.457387
# 합계       -0.412858 -0.504525 -0.541599  0.435196
# 고령자비율     1.000000  0.655428  0.079476 -0.809536
# 외국인비율     0.655428  1.000000 -0.380941 -0.943776
# 여성비율      0.079476 -0.380941  1.000000  0.283602
# 세대당인구    -0.809536 -0.943776  0.283602  1.000000

# %%
# 2-5

check_02_05(pivot_corr)
pivot_corr
# Out:
# 정답입니다! 10점 누적 되었습니다!
# 현재 누적 점수: 60 / 60
#           65세이상고령자   등록외국인 계        세대        여자     한국인 계        합계  \
# 65세이상고령자  1.000000  0.692541  0.993002  0.989734  0.988591  0.989624
# 등록외국인 계   0.692541  1.000000  0.715982  0.668665  0.662168  0.682990
# 세대        0.993002  0.715982  1.000000  0.997588  0.996803  0.998509
# 여자        0.989734  0.668665  0.997588  1.000000  0.999930  0.999780
# 한국인 계     0.988591  0.662168  0.996803  0.999930  1.000000  0.999604
# 합계        0.989624  0.682990  0.998509  0.999780  0.999604  1.000000
# 고령자비율    -0.283126 -0.013428 -0.374200 -0.416096 -0.423040 -0.412858
# 외국인비율    -0.460678  0.201942 -0.468845 -0.520445 -0.525378 -0.504525
# 여성비율     -0.524995 -0.822037 -0.559553 -0.525376 -0.523968 -0.541599
# 세대당인구     0.358033 -0.283314  0.388999  0.449461  0.457387  0.435196
#
#              고령자비율     외국인비율      여성비율     세대당인구
# 65세이상고령자 -0.283126 -0.460678 -0.524995  0.358033
# 등록외국인 계  -0.013428  0.201942 -0.822037 -0.283314
# 세대       -0.374200 -0.468845 -0.559553  0.388999
# 여자       -0.416096 -0.520445 -0.525376  0.449461
# 한국인 계    -0.423040 -0.525378 -0.523968  0.457387
# 합계       -0.412858 -0.504525 -0.541599  0.435196
# 고령자비율     1.000000  0.655428  0.079476 -0.809536
# 외국인비율     0.655428  1.000000 -0.380941 -0.943776
# 여성비율      0.079476 -0.380941  1.000000  0.283602
# 세대당인구    -0.809536 -0.943776  0.283602  1.000000

# %% [markdown]
# ## 3단계: 시각화

# %% [markdown]
# ### *Pandas DataFrame의 Plot기능, Matplotlib.pyplot, Seaborn 등 시각화 Library를 이용하여 문제에서 제시하는 조건에 맞게 시각화하세요.*
# ***

# %%
# 한글 설정
import matplotlib.pyplot as plt
import seaborn as sns
import platform
from matplotlib import font_manager, rc

get_ipython().run_line_magic("matplotlib", "inline")
# %matplotlib inline

path = "C:/Windows/Fonts/malgun.ttf"

if platform.system() == "Darwin":
    rc("font", family="Arial Unicode MS")
elif platform.system == "Windows":
    font_name = font_manager.Fontproperties(fname=path).get_name()
    rc("font", family=font_name)
else:
    print("Unkown system. sorry~~")
# Out:
# Unkown system. sorry~~

# %% [markdown]
# ### **문제 3-1)** 자치구별 고령자비율을 내림차순에 따라 barh 그래프로 시각화 하세요.    (10점)
#
# - 예시
# <br></br>
#     <img src="./images/01-3-1-001.png" style="margin:auto" width=400/>

# %%
import matplotlib.pyplot as plt
from matplotlib import rc
rc('font',family='Malgun Gothic') 

# %matplotlib inline

# %%
df_target_sort = df_target.sort_values(by='고령자비율',ascending=True)


plt.figure(figsize=(10,8))
plt.barh(df_target_sort['자치구'], df_target_sort['고령자비율'], label='고령자비율', height=0.5)
plt.ylabel('자치구')
plt.grid(True)
plt.legend(loc=4)
plt.show()

# %%
# 3-1: barh

# %% [markdown]
# ### **문제 3-2)** 권역별 등록외국인 계를 PIE chart로 시각화 하세요.    (10점)
#
# - 예시
# <br></br>
#     <img src="./images/01-3-2-001.png" style="margin:auto" width=400/>

# %%
df_pivot
# Out:
#      65세이상고령자  등록외국인 계       세대       여자    한국인 계       합계      고령자비율  \
# 권역
# 동남권    286874    20511   876524  1097300  2102113  2122624  13.515064
# 동북권    497385    67938  1342778  1580313  3008988  3076926  16.164997
# 서북권    188566    29239   526451   626811  1165231  1194470  15.786583
# 서남권    454108   124791  1360162  1554745  2950352  3075143  14.767053
# 도심권     91306    37647   248091   279617   506971   544618  16.765145
#
#         외국인비율       여성비율     세대당인구
# 권역
# 동남권  0.966304  51.695449  2.398238
# 동북권  2.207983  51.360124  2.240868
# 서북권  2.447864  52.476077  2.213370
# 서남권  4.058055  50.558462  2.169118
# 도심권  6.912552  51.341858  2.043488

# %%
df_pivot_sort=df_pivot.sort_values(by='등록외국인 계',ascending=True)

plt.figure(figsize=(10,10))
plt.pie(x=df_pivot_sort['등록외국인 계'],labels=df_pivot_sort.index)
plt.ylabel('등록외국인 계')
plt.legend(loc=1)
plt.show()

# %%
# 3-2: Pie

# %% [markdown]
# ### **문제 3-3)** 권역별 외국인비율을 Box plot으로 시각화 하세요.    (10점)
#
# - 예시
# <br></br>
#     <img src="./images/01-3-3-001.png" style="margin:auto" width=400/>

# %%
df_target.head()
# Out:
#           기간  자치구      세대      합계      남자      여자   한국인 계  한국인 남자  한국인 여자  \
# 14  2020.1/4  양천구  177436  460532  226109  234423  456339  224241  232098
# 21  2020.1/4  서초구  173580  434801  207877  226924  430568  205787  224781
# 10  2020.1/4  노원구  217148  535495  258696  276799  531037  256726  274311
# 23  2020.1/4  송파구  279301  680883  329058  351825  674095  325859  348236
# 9   2020.1/4  도봉구  138595  333495  162774  170721  331238  161879  169359
#
#     등록외국인 계  등록외국인 남자  등록외국인 여자  세대당인구  65세이상고령자   권역      고령자비율     외국인비율  \
# 14     4193      1868      2325   2.57     62761  서남권  13.627935  0.910469
# 21     4233      2090      2143   2.48     58332  동남권  13.415793  0.973549
# 10     4458      1970      2488   2.45     82682  동북권  15.440294  0.832501
# 23     6788      3199      3589   2.41     89539  동남권  13.150424  0.996941
# 9      2257       895      1362   2.39     60023  동북권  17.998171  0.676772
#
#          여성비율
# 14  50.902652
# 21  52.190312
# 10  51.690305
# 23  51.671873
# 9   51.191472

# %%
import seaborn as sns

# %%
plt.figure(figsize=(10,10))
sns.boxplot(df_target, x=df_target['권역'], y=df_target['외국인비율'])
plt.title('Boxplot grouped by 권역')
plt.grid(True)
plt.show()

# %%
# 3-3: Boxplot

# %% [markdown]
# ### **문제 3-4)** 자치구별 외국인비율-세대당인구를 Scatter plot에 나타내고, 상관관계에 따른 Regression Line을 시각화 하세요.    (10점)
#
# - 예시
# <br></br>
#     <img src="./images/01-3-4-001.png" style="margin:auto" width=400/>

# %%
df_target.head()
# Out:
#           기간  자치구      세대      합계      남자      여자   한국인 계  한국인 남자  한국인 여자  \
# 14  2020.1/4  양천구  177436  460532  226109  234423  456339  224241  232098
# 21  2020.1/4  서초구  173580  434801  207877  226924  430568  205787  224781
# 10  2020.1/4  노원구  217148  535495  258696  276799  531037  256726  274311
# 23  2020.1/4  송파구  279301  680883  329058  351825  674095  325859  348236
# 9   2020.1/4  도봉구  138595  333495  162774  170721  331238  161879  169359
#
#     등록외국인 계  등록외국인 남자  등록외국인 여자  세대당인구  65세이상고령자   권역      고령자비율     외국인비율  \
# 14     4193      1868      2325   2.57     62761  서남권  13.627935  0.910469
# 21     4233      2090      2143   2.48     58332  동남권  13.415793  0.973549
# 10     4458      1970      2488   2.45     82682  동북권  15.440294  0.832501
# 23     6788      3199      3589   2.41     89539  동남권  13.150424  0.996941
# 9      2257       895      1362   2.39     60023  동북권  17.998171  0.676772
#
#          여성비율
# 14  50.902652
# 21  52.190312
# 10  51.690305
# 23  51.671873
# 9   51.191472

# %%
fd=np.polyfit(df_target['외국인비율'],df_target['세대당인구'],1)
f1 = np.poly1d(fd)
f1
# Out:
# poly1d([-0.0415866 ,  2.35655596])

# %%
x = np.linspace(0,8)
x
# Out:
# array([0.        , 0.16326531, 0.32653061, 0.48979592, 0.65306122,
#        0.81632653, 0.97959184, 1.14285714, 1.30612245, 1.46938776,
#        1.63265306, 1.79591837, 1.95918367, 2.12244898, 2.28571429,
#        2.44897959, 2.6122449 , 2.7755102 , 2.93877551, 3.10204082,
#        3.26530612, 3.42857143, 3.59183673, 3.75510204, 3.91836735,
#        4.08163265, 4.24489796, 4.40816327, 4.57142857, 4.73469388,
#        4.89795918, 5.06122449, 5.2244898 , 5.3877551 , 5.55102041,
#        5.71428571, 5.87755102, 6.04081633, 6.20408163, 6.36734694,
#        6.53061224, 6.69387755, 6.85714286, 7.02040816, 7.18367347,
#        7.34693878, 7.51020408, 7.67346939, 7.83673469, 8.        ])

# %%
plt.figure(figsize=(10,10))
plt.scatter(x = df_target['외국인비율'],y=df_target['세대당인구'])
plt.plot(x,f1(x) , lw=3 , )
plt.xlabel('외국인비율')
plt.ylabel('세대당인구')
plt.show()

# %%
sns.lmplot(df_target, x='외국인비율', y='세대당인구',height=10);
plt.xlabel('외국인비율')
plt.ylabel('세대당인구')
plt.show()
# Out:
# C:\Users\user\miniconda3\envs\ds_study\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# 3-4: scatterplot + regression

# %% [markdown]
# ***
#
# ### 🎊 문제가 끝났습니다. 제출양식과 일정에 맞춰 제출해주시기를 바랍니다!
#
# ### 제출양식
# - 이 파일은 EDA TEST 1회차 노트북입니다. 따라서 제출시 파일명은 아래와 같습니다.
# - [DS]edalvtest_01_yourname.ipynb
#
# ***

# %% [markdown]
# # 문의사항 및 의견이 있는 경우 작성해주세요.
